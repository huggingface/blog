# %% [markdown]
# <a href="https://colab.research.google.com/github/patrickvonplaten/notebooks/blob/master/Fine_Tune_XLSR_Wav2Vec2_on_Turkish_ASR_with_%F0%9F%A4%97_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Fine-tuning XLSR-Wav2Vec2 for Multi-Lingual ASR with 🤗 Transformers**

# %% [markdown]
# Wav2Vec2 is a pretrained model for Automatic Speech Recognition (ASR) and was released in [September 2020](https://ai.facebook.com/blog/wav2vec-20-learning-the-structure-of-speech-from-raw-audio/) by Alexei Baevski, Michael Auli, and Alex Conneau.  Soon after the superior performance of Wav2Vec2 was demonstrated on the English ASR dataset LibriSpeech, *Facebook AI* presented XLSR-Wav2Vec2 (click [here](https://arxiv.org/abs/2006.13979)). XLSR stands for *cross-lingual  speech representations* and refers to XLSR-Wav2Vec2`s ability to learn speech representations that are useful across multiple languages.
#
# Similar to Wav2Vec2, XLSR-Wav2Vec2 learns powerful speech representations from hundreds of thousands of hours of speech in more than 50 languages of unlabeled speech. Similar, to [BERT's masked language modeling](http://jalammar.github.io/illustrated-bert/), the model learns contextualized speech representations by randomly masking feature vectors before passing them to a transformer network.
#
# ![wav2vec2_structure](https://raw.githubusercontent.com/patrickvonplaten/scientific_images/master/xlsr_wav2vec2.png)
#
# The authors show for the first time that massively pretraining an ASR model on cross-lingual unlabeled speech data, followed by language-specific fine-tuning on very little labeled data achieves state-of-the-art results. See Table 1-5 of the official [paper](https://arxiv.org/pdf/2006.13979.pdf).

# %% [markdown]
# In this notebook, we will give an in-detail explanation of how XLSR-Wav2Vec2's pretrained checkpoint can be fine-tuned on a low-resource ASR dataset of any language. Note that in this notebook, we will fine-tune XLSR-Wav2Vec2 without making use of a language model. It is much simpler and more efficient to use XLSR-Wav2Vec2 without a language model, but better results can be achieved by including a language model.
#
# For demonstration purposes, we fine-tune the [wav2vec2-large-xlsr-53](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) on the low resource Turkish ASR dataset of [Common Voice](https://huggingface.co/datasets/common_voice) that contains just ~6h of validated training data.

# %% [markdown]
# XLSR-Wav2Vec2 is fine-tuned using Connectionist Temporal Classification (CTC), which is an algorithm that is used to train neural networks for sequence-to-sequence problems and mainly in Automatic Speech Recognition and handwriting recognition.
#
# I highly recommend reading the blog post [Sequence Modeling with CTC (2017)](https://distill.pub/2017/ctc/) very well-written blog post by Awni Hannun.

# %% [markdown]
# Before we start, let's install both `datasets` and `transformers` from master. Also, we need the `torchaudio` and `librosa` package to load audio files and the `jiwer` to evaluate our fine-tuned model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric ${}^1$.

# %%
# %%capture
# !pip install git+https://github.com/huggingface/datasets.git
# !pip install git+https://github.com/huggingface/transformers.git
# !pip install torchaudio
# !pip install librosa
# !pip install jiwer

# %% [markdown]
# ---
#
# ${}^1$ In the [paper](https://arxiv.org/pdf/2006.13979.pdf), the model was evaluated using the phoneme error rate (PER), but by far the most common metric in ASR is the word error rate (WER). To keep this notebook as general as possible we decided to evaluate the model using WER.

# %% [markdown]
# ## Prepare Data, Tokenizer, Feature Extractor

# %% [markdown]
# ASR models transcribe speech to text, which means that we both need a feature extractor that processes the speech signal to the model's input format, *e.g.* a feature vector, and a tokenizer that processes the model's output format to text.
#
# In 🤗 Transformers, the XLSR-Wav2Vec2 model is thus accompanied by both a tokenizer, called [Wav2Vec2CTCTokenizer](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2ctctokenizer), and a feature extractor, called [Wav2Vec2FeatureExtractor](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2featureextractor).
#
# Let's start by creating the tokenizer responsible for decoding the model's predictions.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %% [markdown]
# The [pretrained Wav2Vec2 checkpoint]( ) maps the speech signal to a sequence of context representations as illustrated in the figure above. A fine-tuned XLSR-Wav2Vec2 checkpoint needs to map this sequence of context representations to its corresponding transcription so that a linear layer has to be added on top of the transformer block (shown in yellow). This linear layer is used to classifies each context representation to a token class analogous how, *e.g.*, after pretraining a linear layer is added on top of BERT's embeddings for further classification - *cf.* with *"BERT"* section of this [blog post](https://huggingface.co/blog/warm-starting-encoder-decoder).
#
# The output size of this layer corresponds to the number of tokens in the vocabulary, which does **not** depend on XLSR-Wav2Vec2's pretraining task, but only on the labeled dataset used for fine-tuning. So in the first step, we will take a look at Timit and define a vocabulary based on the dataset's transcriptions.

# %% [markdown]
# First, let's go to [Common Voice](https://commonvoice.mozilla.org/en) and pick your favorite language you would like to fine-tune XLSR-Wav2Vec2 on. For this notebook, we will use Turkish.
#
# **Note**: Most likely, the common voice link has expired. In this case, just go to [Common Voice's dataset website](https://commonvoice.mozilla.org/en/datasets), select your language, *e.g.* `Turkish`, enter your email address to get the "*Download*" button, click right, and click `Copy link address` to fill it in the cell below.

# %%
# !wget "https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-6.1-2020-12-11/tr.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3G23VQA5S%2F20210312%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210312T064856Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEIj%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDKZIPKux%2BmNHRNIsviKSBNDlKP4z8BJGh7lr6j6zkLhvCmkVA8f7Ot4KR52ZpaRK1eP0KRvKdrAvWdk4F0%2FWiPb5lRkDxtfA5gQE6ntJytUzRQfriVpYDHqSCGM7YEaG1ng1XK47dzO0%2FfcwpmyCfpRnZxw1gfs9oH%2BiFub530LRxeuHjeSDrbYT0hLPSXHQX5QRVVhyNLpqd%2F%2Bgqee5JzpCF5AyVS7%2Fz8YTwnz75IWD%2BoPwr%2FFhW0wiZoj4LP%2F6dVi0GhDSyh9w6n%2FthS%2FkSod1xYDUPpN0FFU1ZFYsaJjNr9VYdBhM%2FRUv0y2mXgSuMCviJrE7cv23wu7t4wTT3ELkAKDvMlGC3IgBqd1okQUp2AQRlNKsor38lcqBNZCJfg%2FdF%2Fve7T5NBi3FG0e7TpcnNyaVhL7efFaI2BuuQhzu%2FX7HR3Dy4P7Q5MBz6FFQiVPWq%2B9eOJY8FSP%2Fc%2B7XNIiQPPjwYem0nhM%2FPAfRBkysc9vLSOJU%2FlWlzlPVc94EQMjlYwj3aBjswi5t6A42%2FNxAvNvJrFHOL0Hk1xlVUzRSVNo66NTD5%2BvHcM6UStOjiCYruFCLHk3%2FuyKmLEr7dieX%2BMblLNBQ%2F1JWz1E4hTAc7tXnCkhOknJQ0d%2BfsbPT%2FoWW562oUWLEdrC38I5T7BbuyC0v9X2vzhMA7jVh9pJdl4%2Bk82yXowTwT2AFBYlBv6CpuWrtrnFtYOrgSGboYCG%2FKPWLrIIGMirfCq6%2F%2BD0PuXf%2FQiEZXz8lgNBNuqTVH7enGlPXfW91sRoGH%2FV15J0XwYM%3D&X-Amz-Signature=40b9453607def83d314725a8f9986ee17f50db185999e14a36817bff03f5a6a1&X-Amz-SignedHeaders=host"
# Out:
# The name is too long, 1189 chars total.
# Trying to shorten...
# New name is tr.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3G23VQA5S%2F20210312%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210312T064856Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEIj%2F%2F%2F%2F%2F%2F%2F%2F%2F%.
# --2021-03-12 06:52:07--  https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-6.1-2020-12-11/tr.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3G23VQA5S%2F20210312%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210312T064856Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEIj%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDKZIPKux%2BmNHRNIsviKSBNDlKP4z8BJGh7lr6j6zkLhvCmkVA8f7Ot4KR52ZpaRK1eP0KRvKdrAvWdk4F0%2FWiPb5lRkDxtfA5gQE6ntJytUzRQfriVpYDHqSCGM7YEaG1ng1XK47dzO0%2FfcwpmyCfpRnZxw1gfs9oH%2BiFub530LRxeuHjeSDrbYT0hLPSXHQX5QRVVhyNLpqd%2F%2Bgqee5JzpCF5AyVS7%2Fz8YTwnz75IWD%2BoPwr%2FFhW0wiZoj4LP%2F6dVi0GhDSyh9w6n%2FthS%2FkSod1xYDUPpN0FFU1ZFYsaJjNr9VYdBhM%2FRUv0y2mXgSuMCviJrE7cv23wu7t4wTT3ELkAKDvMlGC3IgBqd1okQUp2AQRlNKsor38lcqBNZCJfg%2FdF%2Fve7T5NBi3FG0e7TpcnNyaVhL7efFaI2BuuQhzu%2FX7HR3Dy4P7Q5MBz6FFQiVPWq%2B9eOJY8FSP%2Fc%2B7XNIiQPPjwYem0nhM%2FPAfRBkysc9vLSOJU%2FlWlzlPVc94EQMjlYwj3aBjswi5t6A42%2FNxAvNvJrFHOL0Hk1xlVUzRSVNo66NTD5%2BvHcM6UStOjiCYruFCLHk3%2FuyKmLEr7dieX%2BMblLNBQ%2F1JWz1E4hTAc7tXnCkhOknJQ0d%2BfsbPT%2FoWW562oUWLEdrC38I5T7BbuyC0v9X2vzhMA7jVh9pJdl4%2Bk82yXowTwT2AFBYlBv6CpuWrtrnFtYOrgSGboYCG%2FKPWLrIIGMirfCq6%2F%2BD0PuXf%2FQiEZXz8lgNBNuqTVH7enGlPXfW91sRoGH%2FV15J0XwYM%3D&X-Amz-Signature=40b9453607def83d314725a8f9986ee17f50db185999e14a36817bff03f5a6a1&X-Amz-SignedHeaders=host
# Resolving mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com (mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com)... 52.218.241.88, 2600:1fa0:402c:1081:34da:dce9::
# Connecting to mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com (mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com)|52.218.241.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 620848700 (592M) [application/x-tar]
# Saving to: ‘tr.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3G23VQA5S%2F20210312%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210312T064856Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEIj%2F%2F%2F%2F%2F%2F%2F%2F%2F%.1’
#
# tr.tar.gz?X-Amz-Alg 100%[===================>] 592.09M  36.8MB/s    in 17s
#
# 2021-03-12 06:52:24 (35.2 MB/s) - ‘tr.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3G23VQA5S%2F20210312%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210312T064856Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEIj%2F%2F%2F%2F%2F%2F%2F%2F%2F%.1’ saved [620848700/620848700]

# %% [markdown]
# Cool, let's copy the downloaded file name from the output of the cell above and unzip it.

# %%
# !tar -xvzf "tr.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3G23VQA5S%2F20210312%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210312T064856Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEIj%2F%2F%2F%2F%2F%2F%2F%2F%2F%"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318685.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318686.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318687.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318688.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318689.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318690.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318691.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318692.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318693.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318694.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318695.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318696.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318697.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318698.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318699.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318700.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318701.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318702.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318703.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318704.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318705.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318706.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318808.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318809.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318810.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318811.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318812.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318824.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318825.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318827.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318829.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318831.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318848.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318849.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318850.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318851.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318852.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318863.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318864.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318865.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318866.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318867.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318933.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318944.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318945.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318951.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318952.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318953.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318964.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318965.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318966.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318968.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21318969.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319059.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319062.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319064.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319068.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319070.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319964.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319965.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319966.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319967.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319968.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319989.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319990.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319991.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319992.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21319993.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21320009.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21320010.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21320011.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21320012.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21320013.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322248.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322249.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322250.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322251.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322252.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322258.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322259.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322260.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322261.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322262.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322263.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322264.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322265.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322266.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21322267.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324791.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324792.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324793.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324794.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324795.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324796.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324797.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324798.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324799.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324800.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324881.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324882.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324883.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324884.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324885.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324886.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324887.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324888.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324889.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324890.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324891.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324892.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324893.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324894.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21324895.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325135.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325136.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325137.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325138.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325139.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325140.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325141.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325142.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325143.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325149.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325151.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325153.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325155.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325157.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325160.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325161.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325164.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325166.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325169.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325171.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325174.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325176.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325178.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325179.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325180.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325201.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325203.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325205.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21325210.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327027.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327028.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327029.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327030.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327031.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327754.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327755.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327757.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327758.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21327760.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328542.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328548.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328553.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328555.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328556.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328577.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328578.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328579.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328580.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328581.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328595.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328598.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328599.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328600.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21328601.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21335451.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21335452.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21335453.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21335454.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21335455.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337636.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337637.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337639.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337641.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337642.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337643.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337644.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337645.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337646.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337647.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337678.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337679.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337680.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337681.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337683.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337693.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337694.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337696.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337698.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21337700.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340527.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340528.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340529.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340530.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340531.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340532.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340533.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340534.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340535.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340536.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340537.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340538.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340539.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340540.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340541.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340542.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340543.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340544.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340545.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340546.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340547.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340548.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340549.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340550.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340551.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340552.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340553.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340554.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340555.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340556.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340557.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340558.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340559.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340560.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340561.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340567.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340568.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340569.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340570.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340571.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340577.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340578.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340579.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340580.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340581.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340587.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340588.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340589.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340590.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340591.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340597.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340598.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340599.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340600.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340601.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340607.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340608.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340609.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340610.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340611.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340612.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340613.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340614.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340615.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340616.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340622.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340623.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340624.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340625.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340626.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340627.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340628.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340629.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340630.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340631.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340647.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340648.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340649.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340650.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340651.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340657.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340658.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340659.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340660.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340661.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340662.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340663.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340664.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340665.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340666.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340667.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340668.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340669.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340670.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340671.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340672.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340673.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340674.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340675.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340676.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340682.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340683.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340684.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340685.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340686.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340692.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340693.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340694.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340695.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340696.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340697.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340698.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340699.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340700.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340701.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340712.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340713.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340714.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340715.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340716.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340717.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340718.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340719.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340720.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340721.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340727.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340728.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340729.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340730.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340731.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340732.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340733.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340734.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340735.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340736.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340742.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340743.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340744.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340745.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340746.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340747.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340748.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340749.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340750.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340751.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340762.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340763.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340764.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340765.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340766.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340767.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340768.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340769.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340770.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340771.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340772.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340773.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340775.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340777.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340779.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340787.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340788.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340789.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340790.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340791.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340797.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340798.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340799.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340800.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340801.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340811.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340813.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340814.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340815.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340816.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340822.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340823.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340824.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340825.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340826.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340834.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340836.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340839.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340840.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340841.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340847.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340848.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340849.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340850.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340851.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340857.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340858.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340859.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340860.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340861.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340862.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340863.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340864.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340865.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340866.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340872.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340873.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340874.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340875.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340876.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340877.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340879.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340881.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340883.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340885.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340887.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340888.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340889.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340890.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340891.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340897.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340899.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340900.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340901.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340902.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340903.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340904.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340905.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340906.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340907.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340908.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340909.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340910.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21340911.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341034.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341035.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341039.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341042.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341043.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341044.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341045.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341046.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341047.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341048.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341055.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341057.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341058.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341059.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341060.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341063.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341064.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341065.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341066.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341067.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341078.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341079.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341080.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341081.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341082.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341088.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341089.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341090.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341091.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341092.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341103.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341105.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341106.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341107.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341108.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341109.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341110.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341111.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341112.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341343.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341344.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341345.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341346.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341347.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341353.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341354.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341355.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341356.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21341357.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342010.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342011.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342012.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342013.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342014.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342020.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342021.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342022.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342023.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342025.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342035.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342036.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342037.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342038.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342039.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342050.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342051.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342052.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342053.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342054.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342065.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342066.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342067.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342068.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342069.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342075.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342076.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342077.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342078.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342079.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342090.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342091.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342092.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342093.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342094.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342100.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342101.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342102.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342103.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342104.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342110.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342111.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342112.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342113.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342114.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342115.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342116.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342117.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342118.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342119.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342135.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342136.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342137.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342138.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342139.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342140.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342141.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342142.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342143.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342144.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342154.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342155.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342157.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342158.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342159.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342160.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342161.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342162.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342163.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342164.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342170.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342171.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342172.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342173.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342174.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342180.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342181.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21342182.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21344712.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21344713.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21344714.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21344715.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21344716.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346389.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346390.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346391.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346392.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346393.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346395.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346397.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346399.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346400.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346402.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346404.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346405.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346406.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346407.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346408.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346409.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346410.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346411.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346412.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346413.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346414.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346415.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346416.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346417.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346418.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346419.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346420.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346421.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346422.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346423.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346424.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346425.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346426.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346427.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346428.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346429.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346430.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346432.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346433.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346434.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346437.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346438.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346439.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346440.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346441.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346442.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346443.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346444.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346445.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346446.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346447.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346448.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346449.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346450.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346451.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346452.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346453.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346454.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21346456.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347559.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347560.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347561.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347562.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347563.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347569.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347570.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347571.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347572.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347613.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347614.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347615.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347616.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347617.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347634.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347637.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347640.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347641.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347642.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347663.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347664.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347665.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347666.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347670.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347683.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347684.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347685.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347686.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347687.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347713.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347714.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347715.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347720.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21347722.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351350.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351351.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351352.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351353.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351389.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351390.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351391.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351392.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351393.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351404.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351405.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351406.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351407.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351408.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351419.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351420.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351421.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351422.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351423.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351429.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351430.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351431.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351432.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351433.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351445.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351446.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351447.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351448.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351459.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351460.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351461.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351462.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351463.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351479.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351480.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351481.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351482.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351483.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351489.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351490.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351491.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351492.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351493.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351494.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351495.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351496.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351497.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351498.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351524.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351525.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351526.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351527.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351528.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351529.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351530.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351531.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351532.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351533.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351539.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351540.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351542.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351544.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21351546.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356201.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356202.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356203.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356204.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356205.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356562.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356563.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356564.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356565.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356566.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356567.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356568.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356570.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356574.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356576.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356577.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356578.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356579.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356580.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356581.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356582.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356583.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356584.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356585.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356586.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356587.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356588.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356589.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356590.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356591.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356597.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356598.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356599.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356600.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356601.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356602.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356603.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356604.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356605.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356606.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356612.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356613.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356614.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356615.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356616.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356617.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356618.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356619.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356621.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356622.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21356623.mp3
# ...
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486407.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486409.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486410.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486411.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486412.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486454.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486455.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486456.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486457.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22486458.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487171.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487172.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487174.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487175.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487176.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487216.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487217.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487218.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487219.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487220.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487249.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487250.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487252.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487253.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22487255.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22498669.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22498670.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22498671.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22498672.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22498673.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22519395.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22519396.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22519398.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22519399.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22519400.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22574769.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22574771.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22574772.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22574773.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22574775.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22599679.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22599680.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22599683.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22599685.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22599687.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22709153.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22709154.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22720098.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_22734584.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23004601.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23004605.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23334067.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23334068.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23345591.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23385755.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23388477.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23650398.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23650399.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23650400.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23650401.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23650402.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23655146.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23655147.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23655148.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23655149.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23655150.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23660891.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23660892.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23660893.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23660894.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23660895.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667814.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667815.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667816.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667817.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667818.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667819.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667820.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667821.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23667822.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23668256.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23668257.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23668258.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23668259.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23668260.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23668261.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23668262.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676478.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676479.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676480.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676481.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676675.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676676.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676677.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23676678.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23683313.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23706336.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23706337.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23706338.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23706339.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23706340.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714923.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714924.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714925.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714926.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714927.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714938.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714939.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714940.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23714941.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721239.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721240.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721241.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721242.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721243.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721244.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721248.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721250.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23721252.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23729641.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23742857.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23742858.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23742859.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23742860.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23747110.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23868570.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23868571.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872315.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872318.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872320.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872323.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872324.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872325.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872326.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872327.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872328.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872329.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872330.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872332.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872334.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872335.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872338.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872421.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872422.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872423.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872424.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872425.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872426.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872427.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872428.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872429.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872430.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872431.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872432.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872433.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872434.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872435.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872652.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872653.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872654.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872655.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23872656.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23883206.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23883207.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23883208.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23883209.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23883210.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23888455.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23888456.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23888459.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23888461.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23888464.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890985.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890986.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890987.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890988.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890989.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890990.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890991.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890992.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890993.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890994.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890995.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890996.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890997.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23890998.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898303.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898304.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898305.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898306.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898307.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898343.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898344.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898345.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898346.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898347.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898348.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898349.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898350.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898351.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898352.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898403.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898404.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898405.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898406.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898407.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898409.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898410.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898412.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898413.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898415.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898423.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898424.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898425.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898427.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23898430.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901095.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901096.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901097.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901098.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901099.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901100.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901101.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901102.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901103.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901104.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901105.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901106.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901107.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901108.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901109.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901880.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901882.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901883.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901885.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23901886.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919445.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919446.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919447.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919448.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919449.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919455.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919456.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919457.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919458.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23919459.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23949136.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23949137.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23949138.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23949139.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23964506.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23964507.mp3
# cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_23964508.mp3

# %% [markdown]
# The data is now saved under `./cv-corpus-6.1-2020-12-11`. We can leverage `datasets` now to preprocess the dataset.

# %% [markdown]
# Let's start by loading the dataset and taking a look at its structure. [Common Voice](https://huggingface.co/datasets/common_voice) has many different splits including `invalidated`, which refers to data that was not rated as "clean enough" to be considered useful. Because the Turkish dataset is so small, we will merge both the validation and training data into a training dataset and simply use the test data for validation.

# %%
from datasets import load_dataset, load_metric

common_voice_train = load_dataset("common_voice", "tr", data_dir="./cv-corpus-6.1-2020-12-11", split="train+validation")
common_voice_test = load_dataset("common_voice", "tr", data_dir="./cv-corpus-6.1-2020-12-11", split="test")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=4662.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=5925.0, style=ProgressStyle(description…
# Using custom data configuration tr-ad9f7b76efa9f3a0
# Downloading and preparing dataset common_voice/tr (download: Unknown size, generated: 2.33 MiB, post-processed: Unknown size, total: 2.33 MiB) to /root/.cache/huggingface/datasets/common_voice/tr-ad9f7b76efa9f3a0/6.1.0/32954a9015faa0d840f6c6894938545c5d12bc5d8936a80079af74bf50d71564...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset common_voice downloaded and prepared to /root/.cache/huggingface/datasets/common_voice/tr-ad9f7b76efa9f3a0/6.1.0/32954a9015faa0d840f6c6894938545c5d12bc5d8936a80079af74bf50d71564. Subsequent calls will reuse this data.
# Using custom data configuration tr-ad9f7b76efa9f3a0
# Reusing dataset common_voice (/root/.cache/huggingface/datasets/common_voice/tr-ad9f7b76efa9f3a0/6.1.0/32954a9015faa0d840f6c6894938545c5d12bc5d8936a80079af74bf50d71564)

# %% [markdown]
# Many ASR datasets only provide the target text, `'sentence'` for each audio file `'path'`. Common Voice actually provides much more information about each audio file, such as the `'accent'`, etc. However, we want to keep the notebook as general as possible, so that we will only consider the transcribed text for fine-tuning.

# %%
common_voice_train = common_voice_train.remove_columns(["accent", "age", "client_id", "down_votes", "gender", "locale", "segment", "up_votes"])
common_voice_test = common_voice_test.remove_columns(["accent", "age", "client_id", "down_votes", "gender", "locale", "segment", "up_votes"])

# %% [markdown]
# Let's write a short function to display some random samples of the dataset and run it a couple of times to get a feeling for the transcriptions.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(common_voice_train.remove_columns(["path"]), num_examples=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Jonuz, kısa süreli görevi kabul eden tek adaydı.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Biz umudumuzu bu mücadeleden almaktayız.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sergide beş Hırvat yeniliği sergilendi.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Herşey adıyla bilinmeli.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Kuruluş özelleştirmeye hazır.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Yerleşim yerlerinin manzarası harika.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Olayların failleri bulunamadı.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Fakat bu çabalar boşa çıktı.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Projenin değeri iki virgül yetmiş yedi milyon avro.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Büyük yeniden yapım projesi dört aşamaya bölündü.</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Efes ise yılda dört milyon avro gelir sağlıyor.</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Yeni tesisin yıllık kapasitesi sekiz virgül beş kilowatt saat olacak.</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Beşli otuz gün gözaltında tutuldu.</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Güvenlik tedbirleri.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Olayla ilgili iki kişi daha suçlandı.</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>"Gül'ün bu gelişme üzerine gitmesi bekleniyor."</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>"Türkiye Kaddafi'ye karşı görüşlerini daha güçlü bir şekilde dile getirmekte neden tereddüt ediyor?"</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>"Lukiç Lahey'e iadesine karşı çıkmadı."</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Egmont Grubu bu meselelere nasıl yaklaşıyor?</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Eski rekor yirmi dört saat içinde bin beş yüz sekiz km idi.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Alright! The transcriptions look fairly clean. Having translated the transcribed sentences (I'm sadly not a native speaker in Turkish), it seems that the language corresponds more to written text than noisy dialogue. This makes sense taking into account that [Common Voice](https://huggingface.co/datasets/common_voice) is a crowd-sourced read speech corpus.

# %% [markdown]
# We can see that the transcriptions contain some special characters, such as `,.?!;:`. Without a language model, it is much harder to classify speech chunks to such special characters because they don't really correspond to a characteristic sound unit. *E.g.*, the letter `"s"` has a more or less clear sound, whereas the special character `"."` does not.
# Also in order to understand the meaning of a speech signal, it is usually not necessary to include special characters in the transcription.
#
# In addition, we normalize the text to only have lower case letters and append a word separator token at the end.

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["sentence"]).lower() + " "
    return batch

# %%
common_voice_train = common_voice_train.map(remove_special_characters, remove_columns=["sentence"])
common_voice_test = common_voice_test.map(remove_special_characters, remove_columns=["sentence"])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3478.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1647.0), HTML(value='')))

# %%
show_random_elements(common_voice_train.remove_columns(["path"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>birisi beyazlar için dediler</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>maktouf'un cezası haziran ayında sona erdi</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>orijinalin aksine kıyafetler çıkarılmadı</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>bunların toplam değeri yüz milyon avroyu buluyor</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>masada en az iki seçenek bulunuyor</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>bu hiç de haksız bir heveslilik değil</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>bu durum bin dokuz yüz doksanlarda ülkenin bölünmesiyle değişti</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>söz konusu süre altı ay</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ancak bedel çok daha yüksek olabilir</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>başkent fira bir tepenin üzerinde yer alıyor</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Good! This looks better. We have removed most special characters from transcriptions and normalized them to lower-case only.
#
# In CTC, it is common to classify speech chunks into letters, so we will do the same here.
# Let's extract all distinct letters of the training and test data and build our vocabulary from this set of letters.
#
# We write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.
# It is important to pass the argument `batched=True` to the `map(...)` function so that the mapping function has access to all transcriptions at once.

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocab_train = common_voice_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_train.column_names)
vocab_test = common_voice_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_test.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %% [markdown]
# Now, we create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {' ': 33,
#  "'": 23,
#  'a': 10,
#  'b': 4,
#  'c': 8,
#  'd': 15,
#  'e': 24,
#  'f': 31,
#  'g': 26,
#  'h': 16,
#  'i': 29,
#  'j': 0,
#  'k': 11,
#  'l': 27,
#  'm': 22,
#  'n': 9,
#  'o': 12,
#  'p': 36,
#  'q': 19,
#  'r': 7,
#  's': 28,
#  't': 34,
#  'u': 13,
#  'v': 6,
#  'w': 17,
#  'x': 25,
#  'y': 3,
#  'z': 21,
#  'â': 14,
#  'ç': 20,
#  'î': 5,
#  'ö': 30,
#  'ü': 18,
#  'ğ': 1,
#  'ı': 2,
#  'ş': 35,
#  '̇': 32}

# %% [markdown]
# Cool, we see that all letters of the alphabet occur in the dataset (which is not really surprising) and we also extracted the special characters `" "` and `'`. Note that we did not exclude those special characters because:
#
# - The model has to learn to predict when a word is finished or else the model prediction would always be a sequence of chars which would make it impossible to separate words from each other.
# - From the transcriptions above it seems that words that include an apostrophe, such as `maktouf'un` do exist in Turkish, so I decided to keep the apostrophe in the dataset. This might be a wrong assumption though.
#
# One should always keep in mind that the data-preprocessing is a very important step before training your model. E.g., we don't want our model to differentiate between `a` and `A` just because we forgot to normalize the data. The difference between `a` and `A` does not depend on the "sound" of the letter at all, but more on grammatical rules - *e.g.* use a capitalized letter at the beginning of the sentence. So it is sensible to remove the difference between capitalized and non-capitalized letters so that the model has an easier time learning to transcribe speech.
#
# It is always advantageous to get help from a native speaker of the language you would like to transcribe to verify whether the assumptions you made are sensible, *e.g.* I should have made sure that keeping `'`, but removing other special characters is a sensible choice for Turkish.

# %% [markdown]
# To make it clearer that `" "` has its own token class, we give it a more visible character `|`. In addition, we also add an "unknown" token so that the model can later deal with characters not encountered in Timit's training set.
#
# Finally, we also add a padding token that corresponds to CTC's "*blank token*". The "blank token" is a core component of the CTC algorithm. For more information, please take a look at the "Alignment" section [here](https://distill.pub/2017/ctc/).

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 39

# %% [markdown]
# Cool, now our vocabulary is complete and consists of 39 tokens, which means that the linear layer that we will add on top of the pretrained XLSR-Wav2Vec2 checkpoint will have an output dimension of 39.

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %% [markdown]
# Next, we will create the feature extractor.

# %% [markdown]
# ### Create XLSR-Wav2Vec2 Feature Extractor

# %% [markdown]
# Speech is a continuous signal and to be treated by computers, it first has to be discretized, which is usually called **sampling**. The sampling rate hereby plays an important role in that it defines how many data points of the speech signal are measured per second. Therefore, sampling with a higher sampling rate results in a better approximation of the *real* speech signal but also necessitates more values per second.
#
# A pretrained checkpoint expects its input data to have been sampled more or less from the same distribution as the data it was trained on. The same speech signals sampled at two different rates have a very different distribution, *e.g.*, doubling the sampling rate results in data points being twice as long. Thus,
# before fine-tuning a pretrained checkpoint of an ASR model, it is crucial to verify that the sampling rate of the data that was used to pretrain the model matches the sampling rate of the dataset used to fine-tune the model.
#
# XLSR-Wav2Vec2 was pretrained on the audio data of [Babel](https://huggingface.co/datasets/librispeech_asr),
# [Multilingual LibriSpeech (MLS)](https://ai.facebook.com/blog/a-new-open-data-set-for-multilingual-speech-research/), and [Common Voice](https://huggingface.co/datasets/common_voice). Most of those datasets were sampled at 16kHz, so that Common Voice, sampled at 48kHz, has to be downsampled to 16kHz for training. Therefore, we will have to downsample our fine-tuning data to 16kHz in the following.

# %% [markdown]
# A XLSR-Wav2Vec2 feature extractor object requires the following parameters to be instantiated:
#
# - `feature_size`: Speech models take a sequence of feature vectors as an input. While the length of this sequence obviously varies, the feature size should not. In the case of Wav2Vec2, the feature size is 1 because the model was trained on the raw speech signal ${}^2$.
# - `sampling_rate`: The sampling rate at which the model is trained on.
# - `padding_value`: For batched inference, shorter inputs need to be padded with a specific value
# - `do_normalize`: Whether the input should be *zero-mean-unit-variance* normalized or not. Usually, speech models perform better when normalizing the input
# - `return_attention_mask`: Whether the model should make use of an `attention_mask` for batched inference. In general, XLSR-Wav2Vec2 models should **always** make use of the `attention_mask`.

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)

# %% [markdown]
# Great, XLSR-Wav2Vec2's feature extraction pipeline is thereby fully defined!
#
# To make the usage of XLSR-Wav2Vec2 as user-friendly as possible, the feature extractor and tokenizer are *wrapped* into a single `Wav2Vec2Processor` class so that one only needs a `model` and `processor` object.

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# If one wants to re-use the just created processor and the fine-tuned model of this notebook, one can mount his/her google drive to the notebook and save all relevant files there. To do so, please uncomment the following lines.
#
# We will give the fine-tuned model the name `"wav2vec2-large-xlsr-turkish-demo"`.

# %%
# from google.colab import drive
# drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# processor.save_pretrained("/content/gdrive/MyDrive/wav2vec2-large-xlsr-turkish-demo")

# %% [markdown]
# Next, we can prepare the dataset.

# %% [markdown]
# ### Preprocess Data
#
# So far, we have not looked at the actual values of the speech signal but just kept the path to its file in the dataset. `XLSR-Wav2Vec2` expects the audio file in the format of a 1-dimensional array, so in the first step, let's load all audio files into the dataset object.
#
# Let's first check the serialization format of the downloaded audio files by looking at the first training sample.

# %%
common_voice_train[0]
# Out:
# {'path': '/content/cv-corpus-6.1-2020-12-11/tr/clips/common_voice_tr_21921195.mp3',
#  'text': 'pirin sözleri hâlâ yankılanıyor '}

# %% [markdown]
# Alright, the audio file is saved in the `.mp3` format. The `.mp3` format is usually not the easiest format to deal with. We found that the [`torchaudio`](https://pytorch.org/audio/stable/index.html) library works best for reading in `.mp3` data.
#
# An audio file usually stores both its values and the sampling rate with which the speech signal was digitalized. We want to store both in the dataset and write a `map(...)` function accordingly.

# %%
import torchaudio

def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = speech_array[0].numpy()
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch["text"]
    return batch

# %%
common_voice_train = common_voice_train.map(speech_file_to_array_fn, remove_columns=common_voice_train.column_names)
common_voice_test = common_voice_test.map(speech_file_to_array_fn, remove_columns=common_voice_test.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3478.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1647.0), HTML(value='')))

# %% [markdown]
# Great, now we've successfully read in all the audio files, but since we know that Common Voice is sampled at 48kHz, we need to resample the audio files to 16kHz.
#
# Let's make use of the [`librosa`](https://github.com/librosa/librosa) library to downsample the data.

# %%
import librosa
import numpy as np

def resample(batch):
    batch["speech"] = librosa.resample(np.asarray(batch["speech"]), 48_000, 16_000)
    batch["sampling_rate"] = 16_000
    return batch

# %%
common_voice_train = common_voice_train.map(resample, num_proc=4)
common_voice_test = common_voice_test.map(resample, num_proc=4)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='#1', max=870.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=869.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=869.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=870.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=412.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=412.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=412.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=411.0, style=ProgressStyle(description_width='in…

# %% [markdown]
# This seemed to have worked! Let's listen to a couple of audio files to better understand the dataset and verify that the audio was correctly loaded.
#
# **Note**: *You can click the following cell a couple of times to listen to different speech samples.*

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(common_voice_train))

ipd.Audio(data=np.asarray(common_voice_train[rand_int]["speech"]), autoplay=True, rate=16000)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# It can be heard, that the speakers change along with their speaking rate, accent, and background environment, etc. Overall, the recordings sound acceptably clear though, which is to be expected from a crowd-sourced read speech corpus.
#
# Let's do a final check that the data is correctly prepared, by printing the shape of the speech input, its transcription, and the corresponding sampling rate.
#
# **Note**: *You can click the following cell a couple of times to verify multiple samples.*

# %%
rand_int = random.randint(0, len(common_voice_train))

print("Target text:", common_voice_train[rand_int]["target_text"])
print("Input array shape:", np.asarray(common_voice_train[rand_int]["speech"]).shape)
print("Sampling rate:", common_voice_train[rand_int]["sampling_rate"])
# Out:
# Target text: mali sorunlara rağmen bunu tekrar başardı
# Input array shape: (116352,)
# Sampling rate: 16000

# %% [markdown]
# Good! Everything looks fine - the data is a 1-dimensional array, the sampling rate always corresponds to 16kHz, and the target text is normalized.

# %% [markdown]
# Finally, we can process the dataset to the format expected by the model for training. We will again make use of the `map(...)` function.
#
# First, we check that the data samples have the same sampling rate of 16kHz.
# Second, we extract the `input_values` from the loaded audio file. In our case, this includes only normalization, but for other speech models, this step could correspond to extracting, *e.g.* [Log-Mel features](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).
# Third, we encode the transcriptions to label ids.
#
# **Note**: This mapping function is a good example of how the `Wav2Vec2Processor` class should be used. In "normal" context, calling `processor(...)` is redirected to `Wav2Vec2FeatureExtractor`'s call method. When wrapping the processor into the `as_target_processor` context, however, the same method is redirected to `Wav2Vec2CTCTokenizer`'s call method.
# For more information please check the [docs](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#transformers.Wav2Vec2Processor.__call__).

# %%
def prepare_dataset(batch):
    # check that all files have the correct sampling rate
    assert (
        len(set(batch["sampling_rate"])) == 1
    ), f"Make sure all inputs have the same sampling rate of {processor.feature_extractor.sampling_rate}."

    batch["input_values"] = processor(batch["speech"], sampling_rate=batch["sampling_rate"][0]).input_values
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["target_text"]).input_ids
    return batch

# %%
common_voice_train = common_voice_train.map(prepare_dataset, remove_columns=common_voice_train.column_names, batch_size=8, num_proc=4, batched=True)
common_voice_test = common_voice_test.map(prepare_dataset, remove_columns=common_voice_test.column_names, batch_size=8, num_proc=4, batched=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# HBox(children=(FloatProgress(value=0.0, description='#0', max=109.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=109.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=109.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=109.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=52.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=52.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=52.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=52.0, style=ProgressStyle(description_width='ini…

# %% [markdown]
# ## Training
#
# The data is processed so that we are ready to start setting up the training pipeline. We will make use of 🤗's [Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer) for which we essentially need to do the following:
#
# - Define a data collator. In contrast to most NLP models, XLSR-Wav2Vec2 has a much larger input length than output length. *E.g.*, a sample of input length 50000 has an output length of no more than 100. Given the large input sizes, it is much more efficient to pad the training batches dynamically meaning that all training samples should only be padded to the longest sample in their batch and not the overall longest sample. Therefore, fine-tuning XLSR-Wav2Vec2 requires a special padding data collator, which we will define below
#
# - Evaluation metric. During training, the model should be evaluated on the word error rate. We should define a `compute_metrics` function accordingly
#
# - Load a pretrained checkpoint. We need to load a pretrained checkpoint and configure it correctly for training.
#
# - Define the training configuration.
#
# After having fine-tuned the model, we will correctly evaluate it on the test data and verify that it has indeed learned to correctly transcribe speech.

# %% [markdown]
# ### Set-up Trainer
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).
#
# Without going into too many details, in contrast to the common data collators, this data collator treats the `input_values` and `labels` differently and thus applies to separate padding functions on them (again making use of XLSR-Wav2Vec2's context manager). This is necessary because in speech input and output are of different modalities meaning that they should not be treated by the same padding function.
# Analogous to the common data collators, the padding tokens in the labels with `-100` so that those tokens are **not** taken into account when computing the loss.

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
wer_metric = load_metric("wer")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1764.0, style=ProgressStyle(description…

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.
#
# A logit vector $\mathbf{y}_1$ contains the log-odds for each word in the vocabulary we defined earlier, thus $\text{len}(\mathbf{y}_i) =$ `config.vocab_size`. We are interested in the most likely prediction of the model and thus take the `argmax(...)` of the logits. Also, we transform the encoded labels back to the original string by replacing `-100` with the `pad_token_id` and decoding the ids while making sure that consecutive tokens are **not** grouped to the same token in CTC style ${}^1$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# Now, we can load the pretrained `XLSR-Wav2Vec2` checkpoint. The tokenizer's `pad_token_id` must be to define the model's `pad_token_id` or in the case of `Wav2Vec2ForCTC` also CTC's *blank token* ${}^2$. To save GPU memory, we enable PyTorch's [gradient checkpointing](https://pytorch.org/docs/stable/checkpoint.html) and also set the loss reduction to "*mean*".
#
# Because the dataset is quite small (~6h of training data) and because Common Voice is quite noisy, fine-tuning Facebook's [wav2vec2-large-xlsr-53 checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) seems to require some hyper-parameter tuning. Therefore, I had to play around a bit with different values for dropout, [SpecAugment](https://arxiv.org/abs/1904.08779)'s masking dropout rate, layer dropout, and the learning rate until training seemed to be stable enough.
#
# **Note**: When using this notebook to train XLSR-Wav2Vec2 on another language of Common Voice those hyper-parameter settings might not work very well. Feel free to adapt those depending on your use case.

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53", 
    attention_dropout=0.1,
    hidden_dropout=0.1,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.1,
    gradient_checkpointing=True, 
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer)
)
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# The first component of XLSR-Wav2Vec2 consists of a stack of CNN layers that are used to extract acoustically meaningful - but contextually independent - features from the raw speech signal. This part of the model has already been sufficiently trained during pretraining and as stated in the [paper](https://arxiv.org/pdf/2006.13979.pdf) does not need to be fine-tuned anymore.
# Thus, we can set the `requires_grad` to `False` for all parameters of the *feature extraction* part.

# %%
model.freeze_feature_extractor()

# %% [markdown]
# In a final step, we define all parameters related to training.
# To give more explanation on some of the parameters:
# - `group_by_length` makes training more efficient by grouping training samples of similar input length into one batch. This can significantly speed up training time by heavily reducing the overall number of useless padding tokens that are passed through the model
# - `learning_rate` and `weight_decay` were heuristically tuned until fine-tuning has become stable. Note that those parameters strongly depend on the Timit dataset and might be suboptimal for other speech datasets.
#
# For more explanations on other parameters, one can take a look at the [docs](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer#trainingarguments).
#
# **Note**: If one wants to save the trained models in his/her google drive the commented-out `output_dir` can be used instead.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir="/content/gdrive/MyDrive/wav2vec2-large-xlsr-turkish-demo",
  # output_dir="./wav2vec2-large-xlsr-turkish-demo",
  group_by_length=True,
  per_device_train_batch_size=16,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=30,
  fp16=True,
  save_steps=400,
  eval_steps=400,
  logging_steps=400,
  learning_rate=3e-4,
  warmup_steps=500,
  save_total_limit=2,
)

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=common_voice_train,
    eval_dataset=common_voice_test,
    tokenizer=processor.feature_extractor,
)

# %% [markdown]
# ---
#
# ${}^1$ To allow models to become independent of the speaker rate, in CTC, consecutive tokens that are identical are simply grouped as a single token. However, the encoded labels should not be grouped when decoding since they don't correspond to the predicted tokens of the model, which is why the `group_tokens=False` parameter has to be passed. If we wouldn't pass this parameter a word like `"hello"` would incorrectly be encoded, and decoded as `"helo"`.
#
# ${}^2$ The blank token allows the model to predict a word, such as `"hello"` by forcing it to insert the blank token between the two l's. A CTC-conform prediction of `"hello"` of our model would be `[PAD] [PAD] "h" "e" "e" "l" "l" [PAD] "l" "o" "o" [PAD]`.

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take between 180 and 240 minutes depending on the GPU allocated to this notebook. While the trained model yields somewhat satisfying results on *Common Voice*'s test data of Turkish, it is by no means an optimally fine-tuned model. The purpose of this notebook is to demonstrate how XLSR-Wav2Vec2's [checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) can be fine-tuned on a low-resource ASR dataset.
#
# In case you want to use this google colab to fine-tune your model, you should make sure that your training doesn't stop due to inactivity. A simple hack to prevent this is to paste the following code into the console of this tab (*right mouse click -> inspect -> Console tab and insert code*).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='2944' max='3270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2944/3270 4:38:17 < 30:50, 0.18 it/s, Epoch 27/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>400</td>
#       <td>5.216200</td>
#       <td>2.705985</td>
#       <td>1.000000</td>
#       <td>204.768000</td>
#       <td>8.043000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.804600</td>
#       <td>0.446772</td>
#       <td>0.589725</td>
#       <td>209.062900</td>
#       <td>7.878000</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.244300</td>
#       <td>0.402035</td>
#       <td>0.531611</td>
#       <td>202.232700</td>
#       <td>8.144000</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.151700</td>
#       <td>0.406878</td>
#       <td>0.508324</td>
#       <td>206.073700</td>
#       <td>7.992000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.107100</td>
#       <td>0.417614</td>
#       <td>0.495149</td>
#       <td>216.555500</td>
#       <td>7.605000</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.078200</td>
#       <td>0.427536</td>
#       <td>0.480748</td>
#       <td>222.747800</td>
#       <td>7.394000</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.071700</td>
#       <td>0.423708</td>
#       <td>0.463589</td>
#       <td>219.078800</td>
#       <td>7.518000</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# The final WER should be below 0.3 which is reasonable given that state-of-the-art phoneme error rates (PER) are just below 0.1 (see [leaderboard](https://paperswithcode.com/sota/speech-recognition-on-timit)) and that WER is usually worse than PER.
#
# The resulting model of this notebook has been saved to [patrickvonplaten/wav2vec2-base-timit-demo](https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo).

# %% [markdown]
# The training loss goes down and we can see that the WER on the test set also improves nicely. Because this notebook is just for demonstration purposes, we can stop here.
#
# The resulting model of this notebook has been saved to `patrickvonplaten/wav2vec2-large-xlsr-turkish-demo`.
#
# As a final check, let's load the model and verify that it indeed has learned to transcribe Turkish speech.
#
# Let's first load the pretrained checkpoint.

# %%
model = Wav2Vec2ForCTC.from_pretrained("patrickvonplaten/wav2vec2-large-xlsr-turkish-demo").to("cuda")
processor = Wav2Vec2Processor.from_pretrained("patrickvonplaten/wav2vec2-large-xlsr-turkish-demo")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.

# %% [markdown]
# Now, we will just take the first example of the test set, run it through the model and take the `argmax(...)` of the logits to retrieve the predicted token ids.

# %%
input_dict = processor(common_voice_test["input_values"][0], return_tensors="pt", padding=True)

logits = model(input_dict.input_values.to("cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)[0][0]
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function.Failing to do so can result in silent errors that might be hard to debug.

# %% [markdown]
# We adapted `common_voice_test` quite a bit so that the dataset instance does not contain the original sentence label anymore. Thus, we re-use the original dataset to get the label of the first example.

# %%
common_voice_test_transcription = load_dataset("common_voice", "tr", data_dir="./cv-corpus-6.1-2020-12-11", split="test")
# Out:
# Using custom data configuration tr-ad9f7b76efa9f3a0
# Reusing dataset common_voice (/root/.cache/huggingface/datasets/common_voice/tr-ad9f7b76efa9f3a0/6.1.0/32954a9015faa0d840f6c6894938545c5d12bc5d8936a80079af74bf50d71564)

# %% [markdown]
# Finally, we can decode the example.

# %%
print("Prediction:")
print(processor.decode(pred_ids[0]))

print("\nReference:")
print(common_voice_test_transcription["sentence"][0].lower())
# Out:
# Prediction:
# hata küçük şeyler için birbüy bi şeyler kolaluyor ve yenekiçük şeyler için bir bimizi inciltiyoruz
#
# Reference:
# hayatta küçük şeyleri kovalıyor ve yine küçük şeyler için birbirimizi incitiyoruz.

# %% [markdown]
# Alright! The transcription can definitely be recognized from our prediction, but it is far from being perfect. Training the model a bit longer, spending more time on the data preprocessing, and especially using a language model for decoding would certainly improve the model's overall performance.
#
# For a demonstration model on a low-resource language, the results are acceptable, however 🤗.
