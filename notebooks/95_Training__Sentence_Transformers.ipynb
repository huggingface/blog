# %% [markdown]
# # Train and Fine-Tune Sentence Transformers Models - Notebook Companion

# %%
# %%capture
# !pip install sentence-transformers

# %% [markdown]
# ## How Sentence Transformers models work

# %%
from sentence_transformers import SentenceTransformer, models

## Step 1: use an existing language model
word_embedding_model = models.Transformer('microsoft/deberta-v3-small', max_seq_length=500)

## Step 2: use a pool function over the token embeddings
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())

## Join steps 1 and 2 using the modules argument
model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# Some weights of the model checkpoint at microsoft/deberta-v3-small were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head.LayerNorm.weight', 'mask_predictions.classifier.weight', 'mask_predictions.classifier.bias', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.LayerNorm.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'mask_predictions.LayerNorm.bias', 'lm_predictions.lm_head.bias', 'mask_predictions.dense.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.7/dist-packages/transformers/convert_slow_tokenizer.py:435: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   "The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option"
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ## How to prepare your dataset for training a Sentence Transformers model

# %%
# %%capture
# !pip install datasets

# %%
from datasets import load_dataset

dataset_id = "embedding-data/QQP_triplets"
# dataset_id = "embedding-data/sentence-compression"

dataset = load_dataset(dataset_id)
# Out:
# WARNING:datasets.builder:Using custom data configuration embedding-data--QQP_triplets-ff67885711b8d7f7
# WARNING:datasets.builder:Reusing dataset json (/root/.cache/huggingface/datasets/embedding-data___json/embedding-data--QQP_triplets-ff67885711b8d7f7/0.0.0/a3e658c4731e59120d44081ac10bf85dc7e1388126b92338344ce9661907f253)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(f"- The {dataset_id} dataset has {dataset['train'].num_rows} examples.")
print(f"- Each example is a {type(dataset['train'][0])} with a {type(dataset['train'][0]['set'])} as value.")
print(f"- Examples look like this: {dataset['train'][0]}")
# Out:
# - The embedding-data/QQP_triplets dataset has 101762 examples.
# - Each example is a <class 'dict'> with a <class 'dict'> as value.
# - Examples look like this: {'set': {'query': 'Why in India do we not have one on one political debate as in USA?', 'pos': ['Why cant we have a public debate between politicians in India like the one in US?'], 'neg': ['Can people on Quora stop India Pakistan debate? We are sick and tired seeing this everyday in bulk?', 'Why do politicians, instead of having a decent debate on issues going in and around the world, end up fighting always?', 'Can educated politicians make a difference in India?', 'What are some unusual aspects about politics and government in India?', 'What is debate?', 'Why does civic public communication and discourse seem so hollow in modern India?', 'What is a Parliamentary debate?', "Why do we always have two candidates at the U.S. presidential debate. yet the ballot has about 7 candidates? Isn't that a misrepresentation of democracy?", 'Why is civic public communication and discourse so hollow in modern India?', "Aren't the Presidential debates teaching our whole country terrible communication skills and why is deliberate misrepresentation even allowed?", 'Why are most Indian politicians uneducated?', 'Does Indian political leaders capable of doing face to face debates while running for office?', 'What is wrong with the Indian political system and the environment it has built in connection with the people of India? Have parties divided people more?', 'What is a debate?', 'Why do we have legislative council in india?', 'Why does the office of president of India, being politically neutral, not ask for Population control in India?', "Why don't we discuss tax and foreign policies more in Indian elections but are instead obsessed with socialist schemes?", 'Why do Indian politicians lack nationalist thinking?', 'Do you hate indian politicians?', 'Is India facing more stessful times and politically charged atmosphere when compared to Congress regime?', 'Who is the best politician in India? Why?', "We all know about the present condition of Indian politicians; they are all just using us to run their train, but still, they win elections and rule over us. Why aren't people giving their vote to NOTA?", 'Who are clean politicians in India?', 'Why are you not believing in Democracy of India?', 'What does politics in India mean? What are they actually doing?', 'What are the strongest arguments for a debate in favour of brain drain in India and what sources must be used for making a good short speech?', 'Do we really need an election commission in India?', 'Why is there no concept of political correctness in India? Is it a good thing or a bad thing?', 'Why is population control not on agenda of any political party in India?', 'Who are some of the most dangerous or worst politicians in India?']}}

# %% [markdown]
# Convert the examples into `InputExample`s. It might around 10 minutes in Google Colab.

# %%
from tqdm.auto import tqdm
from sentence_transformers import InputExample

train_examples = []
n_examples = 1000 
## For training with the entire dataset you can use `for i in range(dataset['train'].num_rows):`

for i in tqdm(range(n_examples)):
  example = dataset['train']['set'][i]
  train_examples.append(InputExample(texts=[example['query'], example['pos'][0], example['neg'][0]]))
  # Print each 50 examples how the example looks
  if i % 50 == 0:
    print(f"Anchor: {example['query']} --- Positive: {example['pos'][0]} --- Negative: {example['neg'][0]}")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Anchor: Why in India do we not have one on one political debate as in USA? --- Positive: Why cant we have a public debate between politicians in India like the one in US? --- Negative: Can people on Quora stop India Pakistan debate? We are sick and tired seeing this everyday in bulk?
# Anchor: Can imaginary time, energy and gravity exist? --- Positive: Does imaginary gravity exist? --- Negative: How does gravity exist?
# Anchor: What were the books Aman Bansal used for his Jee preparation? --- Positive: Which books were used my Aman Bansal for JEE preparation? --- Negative: What are some good books for IIT JEE preparation for class 10?
# Anchor: How does Donald Trump expect Mexico to pay for his proposed border wall? --- Positive: How Donald Trump will make Mexico pay for the wall? --- Negative: What if Trump's wall isn't a physical wall at all? He said Mexico would pay. What are some financial deterrents the US could impose? Is it possible?
# Anchor: Is World War III on its way right now? --- Positive: Do you think we are on the verge of World War III? --- Negative: Was World War II Inevitable?
# Anchor: When will be end of world? --- Positive: What is the end of this world? --- Negative: Where does the world end?
# Anchor: What is the rule for a "follow on" in Test Cricket? --- Positive: How is follow on is decided in test cricket? --- Negative: What are the rules which are specific to Test Cricket alone?
# Anchor: What is the most followed topic on Quora? --- Positive: What are the 50 topics with the most followers on Quora? --- Negative: What topics on Quora have a high ratio of followers to other measures of the size of the topic (e.g. questions, answers, upvotes)?
# Anchor: How can you make someone think something was their own idea? --- Positive: What is the best way to convince someone to think something? --- Negative: What is the best way to express your thoughts?
# Anchor: How can I lose weight loss? --- Positive: How can I lose weight safely? --- Negative: I am male, 170 cm, 69 kg. I lost 9 kg in the last 6 months by eating well and jogging 2 days a week. But I want to lose at least 7 kg in the next 2 months. What should I do?
# Anchor: What can I do to get better grades? --- Positive: How do I improve my grades? --- Negative: Why do I get bad grades even though I study a lot?
# Anchor: What is means love? --- Positive: What is the exact meaning of love? --- Negative: What does love mean to a woman?
# Anchor: How can one grow a thick beard at a faster rate? --- Positive: How do I grow a beard fast? --- Negative: Why can't I grow a beard?
# Anchor: Where is the best Whirlpool Refrigerator Service Center in Hyderabad? --- Positive: Where is located the best Whirlpool Refrigerator Service Center in Hyderabad? --- Negative: Where is the best Fridge service center in Hyderabad?
# Anchor: Would you rather vote for Donald Trump or Hillary Clinton? Why? --- Positive: Would you rather have Donald Trump or Hillary Clinton be POTUS? --- Negative: Who Monica Lewinsky would vote for, Donald Trump or Hillary Clinton? Why?
# Anchor: How can I reduce my belly fat in 2 months? --- Positive: How can I reduce my belly fat through a diet? --- Negative: What are the best ways to reduce and eliminate belly, abdominal, and thigh fat?
# Anchor: What is your all time favorite book? --- Positive: What is your favorite book, why? --- Negative: Which is your favorite book from the Bible and why?
# Anchor: Why is salt water taffy candy imported in France? --- Positive: Why is Saltwater Taffy candy imported in Mexico? --- Negative: Is salt a consumer product?
# Anchor: Are there any Q & A sites that are better than Quora? --- Positive: Is there an intellectual Q&A site better than Quora? --- Negative: What are the most popular Q&A on Quora?
# Anchor: What are the best cities in USA with low cost of living? --- Positive: What is the best city in USA with low cost living? --- Negative: What are the best low cost places to live in New York City and why?
# Anchor: How can I become more observant? --- Positive: What are ways to become more observant? --- Negative: How does one become more optimistic?
# Anchor: Where can I get weed (cannabis, marijuana) in Bangalore? --- Positive: Where can I get some high quality weed (cannabis,marijuana) in Bangalore? --- Negative: Where can I get some high quality weed (marijuana) in Kerala?
# Anchor: What are the advantages of federalism? --- Positive: What are the advantages of cooperative federalism? --- Negative: What are examples of dual federalism?
# Anchor: Why do people like dimples on a person's face? --- Positive: Do people find dimples attractive? --- Negative: What are back dimples?
# Anchor: How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Gibson Desert? --- Positive: How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Atacama Desert? --- Negative: How cold can Mongolia get?
# Anchor: Who is going to win the presidential election? --- Positive: Who will win the 2016 U.S. presidential election and why? --- Negative: Who will win the 2020 presidential election and why?
# Anchor: What principles do you live your life by? --- Positive: What are the principles with which you live your life and base your decisions? --- Negative: What is you philosophy on life?
# Anchor: How can I enjoy studying? --- Positive: How can I learn to enjoy studying? --- Negative: How do I study when I don't feel like studying?
# Anchor: What are the best albums of any genre? --- Positive: What are the best music albums to listen? --- Negative: What are some of the best music albums of 2012?
# Anchor: How does Sharad Pawar had become what he is today? --- Positive: How did Sharad Pawar become what he is today? --- Negative: What are some mind-blowing facts about Sharad Pawar?
# Anchor: How can someone be an excellent teacher? --- Positive: How I become a good teacher? --- Negative: How do you Get a teacher to like you and do what you want?
# Anchor: What kind of work is done on the ISS? --- Positive: What kind of work do people do on the ISS? Is anyone working there right now? --- Negative: What is the salary of the people working on the ISS?
# Anchor: Why do people use iPhone? --- Positive: Why do you use an iPhone? --- Negative: Why would you buy an iPhone 7?
# Anchor: Which is the best hairstyle for men? --- Positive: What is the best hairstyle for boys? --- Negative: What are some good hairstyles for boys teenagers?
# Anchor: What are the most populated cities in the world? --- Positive: What is the most populated city in the world? --- Negative: Which is the most populated country?
# Anchor: What are the top 10 Bollywood songs? --- Positive: What will be the top 10 Bollywood songs of all time? --- Negative: Which Bollywood movie has the best songs?
# Anchor: When Donald Trump become President, is he required by law to make public his 2017 tax return? --- Positive: Would Donald Trump be legally required to release his tax returns if he became President? --- Negative: Can Congress subpoena the IRS for Trump's tax records?
# Anchor: Do I need to learn data structure and algorithms to become good in embedded system? --- Positive: For an embedded engineer is it necessary to learn algorithms and data structure? --- Negative: Where can I learn about algorithms and data structures efficiently?
# Anchor: Where can I get best assistance in Sydney for buying property? --- Positive: Where can I get very smooth and uncomplicated assistance in Sydney for any property transaction? --- Negative: Where can I get best quality Shop Defits services in Sydney?
# Anchor: Is it worth buying iPhone 7? --- Positive: Is it worth buying the iPhone 7? --- Negative: Is buying an iPhone 6 Plus worth it?
# Anchor: Can trump get elected? --- Positive: Could Trump win? --- Negative: Is Donald Trump likely to win the 2016 election (late 2015 / early 2016)?
# Anchor: How can I publish my book on my own? --- Positive: How can I publish my own book? --- Negative: How can one publish his/her own book in India?
# Anchor: How can I better digest/remember/understand what I read? --- Positive: How can I remember what I've read? --- Negative: How do I remember a book in one reading?
# Anchor: How can I increase my running speed? --- Positive: How do I maximize my running speed? --- Negative: How do I run faster and efficiently during jogging?
# Anchor: What is the best book to learn body language? --- Positive: What are good books to learn about body language? --- Negative: What are the best books for physiology, anatomy and biochemistry?
# Anchor: How can I stay focused in class? --- Positive: How can I stay focused on my school work? --- Negative: How do I stay calm and focused?
# Anchor: How can you cure sulfur burps? --- Positive: How do you cure sulfur burps? --- Negative: What are the uses of sulfur?
# Anchor: Where can I find the total number of tweets for a specific hashtag? --- Positive: Is there a website that can count the number of tweets for a specific hashtag? --- Negative: Is there a way to count all the tweets in a certain hashtag in a given period of time?
# Anchor: What are the safety precautions on handling shotguns proposed by the NRA in the entire U.S. including it’s territories and possessions? 3 --- Positive: What are the safety precautions on handling shotguns proposed by the NRA in Pennsylvania? --- Negative: What are some safe ways to hunt with a tactical shotgun?
# Anchor: What's the difference between butterscotch and caramel? --- Positive: What is the difference between caramel and butterscotch flavor? --- Negative: What is the difference between, whipping cream, heavy cream, and fresh cream?
# Anchor: Why are 1974 Canadian quarter so valuable? --- Positive: Why are 1974 Canadian quarters coveted among collectors? --- Negative: Why are Wohler watches coveted among collectors?
# Anchor: If hearing is associated with abstract thinking, how do people who were born deaf think? --- Positive: How do deaf-born people think? --- Negative: In what way do born Deaf people understand sound?
# Anchor: Why is Twitter down? --- Positive: Why is Twitter down so much? --- Negative: Why have a Twitter?
# Anchor: Why can't India ban the import of Chinese products in India? --- Positive: Why India can't ban cheap, substandard, harmful Chinese goods? --- Negative: Why can't countries afford China's high quality products, but insist to buy low quality Chinese products which Chinese themselves do not want to buy?
# Anchor: Does Mark Zuckerberg intend to run for president in 2020? --- Positive: Is Mark Zuckerberg planning to run for the president in future? --- Negative: Does Mark Zuckerberg go into work regularly?
# Anchor: What went wrong with the polling in the 2016 US presidential election? --- Positive: From statistics, why most polls were wrong in predicting the US election? --- Negative: What are the alternative statistical sampling methods could have been adopted to improve the poll prediction accuracy in the US elections?
# Anchor: How do i get started on machine learning? --- Positive: How can I learn machine learning? --- Negative: Should I learn machine learning?
# Anchor: Do Linux get viruses? Why? --- Positive: Linux Operating System don't get attacked by Viruses. Why? --- Negative: How do computer viruses work?
# Anchor: What kind of a guy do girls look for in a possible boyfriend? --- Positive: What kind of guys do girls fall for? --- Negative: What type of girls do guys like?
# Anchor: Are there any verified angel investors on Quora? --- Positive: Which angel investors are on Quora? --- Negative: What do angel investors look for in a startup?
# Anchor: How to become a dentist? --- Positive: How do I become a dentist? --- Negative: How do you choose a dentist?
# Anchor: Why Nepal was never made a British colony? --- Positive: Why didn't the British invade Nepal during the British Raj in India? --- Negative: What was the actual intention of the British to invade India?
# Anchor: What are the highest paid jobs in India? --- Positive: Which is Highest paid job in India? --- Negative: Which job has the largest salary package in IT field in India and abroad?
# Anchor: What is the difference between a primary and secondary consumer? --- Positive: What are primary and secondary consumers? --- Negative: What are some great examples of secondary consumers?
# Anchor: What are the powers and responsibilities of an IAS officer? --- Positive: What are the powers and responsibilites of an IAS officer? --- Negative: What is the role of an IAS officer in the field of Education?
# Anchor: What programming languages are used in video consoles like the PS4 or Xbox One to develop games? --- Positive: What are the programming languages dev uses on Console games? --- Negative: What language were NES games originally programmed in?
# Anchor: What is the best self-improvement book that you have read and why? --- Positive: What are the best books to read for self improvement? --- Negative: What are some amazing books containing results of life-long experiences learned the hard way?
# Anchor: When can I start using the Indian GPS (of the IRNSS)? --- Positive: When can we start using IRNSS facility? --- Negative: When will 'Indian Regional Navigation Satellite System (IRNSS)' be available for use to public as now all related satellite have been launched?
# Anchor: What would you do if you had an unlimited source of wealth? --- Positive: If you had unlimited money and time, what would you do and why? --- Negative: What would you do if you won a million dollar lottery?
# Anchor: How do I improve my general knowledge? --- Positive: How do I improve general knowledge? --- Negative: How can I improve my knowledge in civil engineering?
# Anchor: Are e-vapes safe? --- Positive: Is vaping safe? Or at least safer? --- Negative: Is vaping marijuana bad?
# Anchor: What is the most stupid thing Donald Trump has said? --- Positive: What are some of the worst things Donald Trump has said?  --- Negative: What are some of Donald Trump’s overused phrases and turns of speech?
# Anchor: Should we be using our real names on Reddit or not? Why? --- Positive: Do you suggest using my real name on reddit.com? --- Negative: Who is RedditCEO on Reddit?
# Anchor: How can you know if someone is lying to you? --- Positive: How do you tell someone that they are lying to you? --- Negative: What is the biggest lie you've told somebody?
# Anchor: Why don't Jimmy Wales answer my questions? --- Positive: Why does Jimmy Wales not respond to my questions? --- Negative: How has Jimmy Wales answered this question twice?
# Anchor: What really happened at MG Road, Bangalore on New Year’s Eve 2017? --- Positive: What exactly happened in Bangalore on the midnight of new year eve? --- Negative: What is it like to have a one-night stand in India? Does it really happen in cities like Bangalore and Mumbai?
# Anchor: Is there any management quota in NIT's? --- Positive: Are there any management quotas in NITs? --- Negative: Is there any management quota at VIT?
# Anchor: Are we near World War 3? --- Positive: Are we heading towards World War III? --- Negative: What is the future of war?
# Anchor: What's the worst thing that ever happens to you for being nice? --- Positive: What is the worst thing ever happened to you for being nice? --- Negative: What is the best thing that ever happened to you for being nice?
# Anchor: Can you convince me to vote for Donald Trump? --- Positive: Why should I vote for Trump? --- Negative: Why shouldn't I vote for Donald Trump?
# Anchor: What is a temper tantrum, psychologically speaking? --- Positive: What is a temper tantrum? --- Negative: How do I deal with toddlers who throw temper tantrums?
# Anchor: How can I stop watching porn? --- Positive: How should a guy stop masturbating? --- Negative: I'm 18 years old, have sex at least 1 time in 2 weeks but I just can't stop masturbating. What can I do?
# Anchor: How can I get meth out of my system in two days? --- Positive: Is there any pill you can buy to flush meth out of your system for a drug test? --- Negative: What is the easiest and safest way to make meth?
# Anchor: What is Jetblue airlines customer service number? --- Positive: What is JetBlue Airlines customer service phone number? --- Negative: What is ths United Airlines Customer Service Number?
# Anchor: What is the inventory source of online airline reservation systems? --- Positive: What is the inventory source of online airline reservation software? --- Negative: How can I make analysis for airline reservation system for study?
# Anchor: What is an easy way to commit suicide? --- Positive: What is the best way to commit suicide in India? --- Negative: How many people commit suicide in India everyday?
# Anchor: What is the future of IT security? --- Positive: What is the future of cyber security? --- Negative: What are the myths about Cyber Security?
# Anchor: What is the best thing you've seen someone do? --- Positive: What is the best thing you have seen someone do? --- Negative: What is the best thing you have ever seen?
# Anchor: Quora: How do you post a question on Quora? --- Positive: How can I ask my question on Quora? --- Negative: How do I ask a question on Yahoo?
# Anchor: What is the best way to flush methamphetamines out of your system? --- Positive: Do cranberry supplements help flush meth out of your system? --- Negative: How do I clean meth in 2-3 days of use?
# Anchor: Which is the best CA coaching in Delhi? --- Positive: What are some good coaching centres for CA IPCC in Delhi? --- Negative: What are some of the best coaching centres for CA IPCC?
# Anchor: Why is talking about my fetish online easier? --- Positive: Why do I prefer talking about my fetish online? --- Negative: What's a fetish?
# Anchor: What are your top 10 favorite songs of all time? Why? --- Positive: What are your top 10 favourite songs of all time? --- Negative: What is your favorite top 10 list of “Sun” songs?
# Anchor: Who is your favourite character in Game of Thrones? And, why? --- Positive: Who is your favorite character on Game of Thrones? And, why? --- Negative: Which Game of Thrones character do you see yourself as?
# Anchor: Why is underwater welding so dangerous? --- Positive: Is it dangerous to be an underwater welder? --- Negative: How do you become an underwater welder?
# Anchor: Why are transition metals good catalysts? --- Positive: Why are transition metals used as catalysts? --- Negative: What is the effect of using metal catalysts in industries?
# Anchor: What are the best source to learn data structure from scratch? --- Positive: Which is the best source to learn data structure from scratch? --- Negative: What are the resources to learn Data Structures using C?
# Anchor: What are your views on Sushma Swaraj's address in UNGA 2016? --- Positive: How do you rate Sushma Swaraj's speech at UNGA 2016? --- Negative: Who is Sushma Swaraj?
# Anchor: Where can I get best assistance for the removal of furniture in Central Coast? --- Positive: Where can I get furniture removal services in Central Coast? --- Negative: What are some furniture removalists for relocating my business?
# Anchor: What are some really good novels? --- Positive: Which are some good novels? --- Negative: What are some of the best novels you have read?

# %%
print(f"We have a {type(train_examples)} of length {len(train_examples)} containing {type(train_examples[0])}'s.")
# Out:
# We have a <class 'list'> of length 1000 containing <class 'sentence_transformers.readers.InputExample.InputExample'>'s.

# %% [markdown]
# We wrap our training dataset into a Pytorch `Dataloader` to shuffle examples and get batch sizes.

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)

# %% [markdown]
# ## Loss functions for training a Sentence Transformers model

# %%
from sentence_transformers import losses

train_loss = losses.TripletLoss(model=model)

# %% [markdown]
# ## How to train a Sentence Transformer model

# %%
num_epochs = 10

warmup_steps = int(len(train_dataloader) * num_epochs * 0.1) #10% of train data

# %%
model.fit(train_objectives=[(train_dataloader, train_loss)],
          epochs=num_epochs,
          warmup_steps=warmup_steps)
# Out:
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/63 [00:00<?, ?it/s]

# %% [markdown]
# ## How to share a Sentence Transformers to the Hugging Face Hub

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
model.save_to_hub(
    "deberta-sentence-transformer", 
    organization="embedding-data",
    train_datasets=["embedding-data/QQP_triplets"],
    exist_ok=True, 
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:43: FutureWarning: Pass token='deberta-sentence-transformer' as keyword args. From version 0.8 passing these as positional arguments will result in an error
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:94: FutureWarning: `name` and `organization` input arguments are deprecated and will be removed in v0.10. Pass `repo_id` instead.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:644: FutureWarning: `create_repo` now takes `token` as an optional positional argument. Be sure to adapt your code!
#   FutureWarning,
# Cloning https://huggingface.co/embedding-data/deberta-sentence-transformer into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/embedding-data/deberta-sentence-transformer into local empty directory.
# Download file pytorch_model.bin:   0%|          | 3.47k/539M [00:00<?, ?B/s]
# Download file spm.model:   0%|          | 3.48k/2.35M [00:00<?, ?B/s]
# Download file tokenizer.json:   0%|          | 3.48k/8.26M [00:00<?, ?B/s]
# Clean file spm.model:   0%|          | 1.00k/2.35M [00:00<?, ?B/s]
# Clean file tokenizer.json:   0%|          | 1.00k/8.26M [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/539M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 3.34k/539M [00:00<?, ?B/s]
# To https://huggingface.co/embedding-data/deberta-sentence-transformer
#    e04b3da..424b703  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/embedding-data/deberta-sentence-transformer
#    e04b3da..424b703  main -> main
# 'https://huggingface.co/embedding-data/deberta-sentence-transformer/commit/424b7034e4e5f4315716c2b5800fa296b02c92d7'

# %% [markdown]
# ## Extra: How to fine-tune a Sentence Transformer model

# %% [markdown]
# Now we will fine-tune our Sentence Transformer model.

# %%
modelB = SentenceTransformer('embedding-data/deberta-sentence-transformer')

# %%
dataset_id = "embedding-data/sentence-compression"
datasetB = load_dataset(dataset_id)
# Out:
# WARNING:datasets.builder:Using custom data configuration embedding-data--sentence-compression-a90dfb3e5e100cf9
# WARNING:datasets.builder:Reusing dataset json (/root/.cache/huggingface/datasets/embedding-data___json/embedding-data--sentence-compression-a90dfb3e5e100cf9/0.0.0/a3e658c4731e59120d44081ac10bf85dc7e1388126b92338344ce9661907f253)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(f"Examples look like this: {datasetB['train']['set'][0]}")
# Out:
# Examples look like this: ["The USHL completed an expansion draft on Monday as 10 players who were on the rosters of USHL teams during the 2009-10 season were selected by the League's two newest entries, the Muskegon Lumberjacks and Dubuque Fighting Saints.", 'USHL completes expansion draft']

# %%
train_examplesB = []
n_examples = 500 
## For training with the entire dataset you can use `for i in range(dataset['train'].num_rows):`

for i in tqdm(range(n_examples)):
  example = datasetB['train']['set'][i]
  train_examplesB.append(InputExample(texts=[example[0], example[1]]))
  # Print each 50 examples how the example looks
  if i % 50 == 0:
    print(f"Anchor: {example[0]} --- Positive: {example[1]}")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Anchor: The USHL completed an expansion draft on Monday as 10 players who were on the rosters of USHL teams during the 2009-10 season were selected by the League's two newest entries, the Muskegon Lumberjacks and Dubuque Fighting Saints. --- Positive: USHL completes expansion draft
# Anchor: A WOMAN has been seriously injured in a collision with a police van in North Devon. --- Positive: Woman seriously injured in collision with police van
# Anchor: The war of words between Team Anna and the government grew intense on Sunday, with Kiran Bedi describing Prime Minister Manmohan Singh as Dhritarashtra. --- Positive: Team Anna's Kiran Bedi describes Manmohan Singh as 'Dhritarashtra'
# Anchor: Moga, July 15 Two unidentified migrant labourers were crushed to death by a speeding vehicle near Chuharchak village here when they were standing near the roadside. --- Positive: Two migrant labourers crushed to death
# Anchor: Partition affected the Indian Muslims adversely, especially those in the country's northern and eastern regions, and its socio-economic impact remains understudied, said Vice President Hamid Ansari on Monday. --- Positive: Partition affected Muslims adversely:
# Anchor: Motorola has just unveiled its gallery of conceptual handsets from the bowels of its design studios in order to celebrate 25 years of the cell phone, and we wish Motorola the best in whatever endeavors they embark upon with their future handset designs. --- Positive: Motorola celebrates 25 years of cell phones
# Anchor: Apple has paid around GBP 3 million to buy 8.2 million shares in UK-based digital radio maker Imagination Technologies. --- Positive: Apple buys into digital radio maker Imagination Technologies
# Anchor: Percy Harvin returned to practice with the Vikings Thursday and reported no lingering effects from his latest migraine episode. --- Positive: Percy Harvin returns to practice
# Anchor: An 8-year-old boy has died after he was hit by a car driven by his own mother at a shopping centre north of Brisbane. --- Positive: Boy dies after being hit by car
# Anchor: War veterans who served in Malaya in the 1950s and 1960s have been denied the right to wear medals of gratitude given to them by the Malaysian government. --- Positive: Veterans denied right to wear medals
# Anchor: New Hampshire State Police say a man was found dead from a self-inflicted gunshot Wednesday afternoon following an hours-long standoff in the town of Mason. --- Positive: Man found dead following standoff
# Anchor: Panera Bread will be opening a new store in North Ridgeville, featuring a drive-thru. --- Positive: Panera Bread to open in North Ridgeville
# Anchor: Organizers have unveiled the route for next year's Dakar Rally, which will start and finish in Buenos Aires and includes a journey through Chile. --- Positive: 2011 Dakar Rally to start in Buenos Aires
# Anchor: The Adam Lambert controversy continues weeks after the 2009 American Music Awards. --- Positive: Adam Lambert controversy continues:
# Anchor: ``We have no other path than to invest in knowledge, work and development'', said President Ben Ali on Friday in an address on the occasion of 'Knowledge Day'. --- Positive: ``We have no other path than to invest in Knowledge, work and development'', says President Ben Ali...
# Anchor: As a former drunken sailor, I quit when I ran out of money. --- Positive: Drunken sailor runs out of money
# Anchor: New York's Senate will reconvene on Wednesday, the Democrats' leaders said on Friday, after the resolution of a leadership brawl let the lawmakers enact 135 bills that had been frozen for nearly five weeks. --- Positive: Ny Senate to reconvene on Wednesday
# Anchor: A cyclist involved in an alleged road rage incident with Shane Warne is suing him for damages to his bike. --- Positive: Cyclist to sue Shane Warne
# Anchor: A massive dust storm descended on the Phoenix area, drastically reducing visibility and delaying flights as strong winds downed trees and left thousands of residents without power. --- Positive: Massive dust storm descends on Phoenix area
# Anchor: Power provider Entergy Corp. affirmed its annual earnings outlook Thursday while saying it expects a 4 percent drop in third-quarter profit. --- Positive: Entergy Corp. affirms earnings outlook
# Anchor: That's right, bath salt is the new cocaine and offers intense highs, hallucination and energy and feelings of anger. --- Positive: Bath salt is the new cocaine:
# Anchor: The Paul McCartney and Heather Mills divorce could drag on FOREVER, or at least it seems that way. --- Positive: Paul McCartney and Heather Mills divorce drags on
# Anchor: On June 13, 2013 Infosys Ltd has announced salary increments for all eligible employees, across the Company, for fiscal year 2014. --- Positive: Infosys announces salary increments for fiscal year 2014
# Anchor: New York metal veterans Virgin Steele are working on a new album and frontman David Defeis has given Metalunderground.com an exclusive first studio update and revealed the tracklisting of the new album, ``The Black Light Bacchanalia.'' --- Positive: Virgin Steele working on new album, gives studio update and reveals tracklisting
# Anchor: The Bundesliga paid tribute to new champions Bayern Munich after they won the league with six games to spare on Saturday. --- Positive: The Bundesliga paid tribute to champions Bayern Munich after they won the league
# Anchor: Karim Benzema rescued a 1-1 draw for leaders Lyon with a brilliant injury-time free-kick at St Etienne in Sunday's French Ligue 1 action. --- Positive: Benzema rescues leaders Lyon
# Anchor: Last time Tila Tequila almost went to rehab, it was because she was trying to get into Dr. Drew's fake famewhore rehab, but now that Tila might be reaching the end of her rope, friends have convinced her to check herself into an actual rehab facility before she does anything to herself. --- Positive: Tila Tequila is going to rehab!
# Anchor: Maharashtra Revenue Minister Narayan Rane on Saturday withdrew his resignation from the state cabinet he had tendered earlier in the month and said he would happily resume his duties as a minister. --- Positive: Narayan Rane withdraws resignation
# Anchor: The August issue of the ACT North American Commercial Vehicle OUTLOOK shows that Class 8 backlogs declined slightly during June, ending a nine-month run of consecutive improvement. --- Positive: Class 8 backlogs decline slightly
# Anchor: The General government budget overall balance was a deficit of 28.7 bln.togrogs. --- Positive: Budget overall balance is deficit
# Anchor: Brit actress Kate Winslet has been named the best international actress at this year's Bambi Awards in Germany. --- Positive: Kate Winslet named best actress
# Anchor: Chennai, March 16 Sadiq Batcha, a close associate of former union communications minister A. Raja and had been questioned by the CBI in the 2G spectrum scam, committed suicide here Wednesday, police said. --- Positive: Raja associate Sadiq Batcha commits suicide
# Anchor: In a media brief published on Sunday November 25, UNAMID announced its support of nomadic education in North Darfur. --- Positive: UNAMID supports nomadic education in North Darfur
# Anchor: French midfielder Arnold Mvuemba has left Pompey after he and the club reached an agreement over cancelling his contract. --- Positive: Arnold Mvuemba leaves Pompey
# Anchor: Alan Howard, the secretive trader at the helm of Brevan Howard Asset Management, and the third-richest hedge fund manager in the UK, has moved to Geneva in a move that will play into the hands of sceptics who question the UK's claim to be Europe's leading centre for hedge funds. --- Positive: Alan Howard moves to Geneva
# Anchor: Two people injured in a Monday crash on state Highway 201 North were treated at Baxter Regional Medical Center and released. --- Positive: Two injured in crash
# Anchor: GE and Fanuc said Tuesday they will dissolve the GE Fanuc Automation Corp. joint venture by the end of the year. --- Positive: GE and Fanuc to dissolve joint venture
# Anchor: Nokia will publish its fourth quarter and annual results 2010 on Thursday, January 27, 2011 at approximately 1 pm Finnish time. --- Positive: Nokia to publish fourth quarter and annual results 2010 on January 27, 2011
# Anchor: Retail stocks fell Thursday after December retail sales and weekly jobless claims both turned out worse than expected, but Target Corp. was among the fewer gainers after the company resumed its share repurchase program. --- Positive: Retail stocks fall;
# Anchor: With college enrollment growing, student debt has stretched to a record number of US households -- nearly 1 in 5 -- with the biggest burdens falling on the young and poor. --- Positive: Student debt stretches to record number of US households
# Anchor: Fiat has denied a German news report that it plans to cut 18,000 jobs and close 10 factories in Europe, should it succeed in its bid to take over GM's European operations. --- Positive: Fiat denies it plans to cut 18,000 jobs, close factories
# Anchor: Greece has been urged to move quickly as coalition talks inch towards a possible national unity cabinet. --- Positive: Greece urged to move quickly
# Anchor: ``The opposition is raising this issue of a separate high court of Haryana, and we will certainly take up this matter strongly in the coming days. The chief justice of India has agreed in principle that Haryana should have a separate high court,'' said Hooda. --- Positive: Haryana will have separate high court:
# Anchor: Back in May of 2008, things didn't look particularly good for Vonage, as the company continued to hemorrhage subscribers, and struggled to make a profit. --- Positive: Things looking better for Vonage?
# Anchor: Cyberspace is buzzing again with news that the ever so popular Sonic drive-in restaurant is coming to Milford. --- Positive: ``Sonic is coming to Milford,CT!!!!''
# Anchor: Specifically, we'll discuss how to preserve wealth in a socialist economy, like an increasing number of the economies in the world today. --- Positive: How to preserve wealth in a socialist economy
# Anchor: Turkmenistan will resume by early January gas supplies to Russia that were halted in April, the deputy chief executive of Russian gas giant Gazprom said Tuesday. --- Positive: Turkmenistan to resume gas supplies to Russia:
# Anchor: Nadine Dorries insists she isn't ``disappointed'' to be first voted off 'I'm A Celebrity ... --- Positive: Nadine Dorries Out of I'm a Celebrity
# Anchor: A man died of sunstroke at the Mahavir Marg here today, sources said. --- Positive: Man dies of sunstroke
# Anchor: US power company Energy Future Holdings, once known as TXU Corp, has hired legal advisors Kirkland & Ellies to lay the groundwork for a potential restructuring, Debtwire reported on Thursday, citing three sources familiar with the matter. --- Positive: Energy Future Holdings hires legal advisors -Debtwire

# %%
train_dataloaderB = DataLoader(train_examplesB, shuffle=True, batch_size=64)
train_lossB = losses.MultipleNegativesRankingLoss(model=modelB)
num_epochsB = 10
warmup_stepsB = int(len(train_dataloaderB) * num_epochsB * 0.1) #10% of train data

# %%
model.fit(train_objectives=[(train_dataloaderB, train_lossB)],
          epochs=num_epochsB,
          warmup_steps=warmup_stepsB)
